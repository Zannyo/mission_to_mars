# %%
# importing necessary stuff

from bs4 import BeautifulSoup
from splinter import Browser
from pprint import pprint
import pymongo
import pandas as pd
import requests

# %%
executable_path = {'executable_path':'C:/Users/zanny/OneDrive/Desktop/Boot Camp/Week 12/5-13-20/Activities/08-Stu_Splinter/Unsolved/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Mars Articles

url = ('https://mars.nasa.gov/news/')

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# print(soup.prettify())

# %%
# pull titles and body from website
results = soup.find_all('div', class_="slide")
for result in results:
    titles = result.find('div', class_="content_title")
    title = titles.find('a').text
    bodies = result.find('div', class_="rollover_description")
    body = bodies.find('div', class_="rollover_description_inner").text
    print('----------------')
    print(title)
    print(body)
# Out:
# ----------------
#
# Alabama High School Student Names NASA's Mars Helicopter
#
#
# Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.
#
# ----------------
#
# Mars Helicopter Attached to NASA's Perseverance Rover
#
#
# The team also fueled the rover's sky crane to get ready for this summer's history-making launch.
#
# ----------------
#
# NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes
#
#
# After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.
#
# ----------------
#
# 10.9 Million Names Now Aboard NASA's Perseverance Mars Rover
#
#
# As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars.
#
# ----------------
#
# Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover
#
#
# NASA chose a seventh-grader from Virginia as winner of the agency's "Name the Rover" essay contest. Alexander Mather's entry for "Perseverance" was voted tops among 28,000 entries.
#
# ----------------
#
# NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network
#
#
# Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.

# %%
# Mars Pics

url = ('https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars')

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# print(soup.prettify())

# %%
images = soup.find_all('a', class_="fancybox")
print(images)
# Out:
# [<a class="button fancybox" data-description="NASA's Cassini spacecraft reveals the differences in the composition of surface materials around hydrocarbon lakes at Titan." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/mediumsize/PIA17470_ip.jpg" data-link="/spaceimages/details.php?id=PIA17470" data-title="Titan's Northern Lakes: Salt Flats?" id="full_image">
# 					FULL IMAGE
# 				  </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the summit caldera on Arsia Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23932_hires.jpg" data-link="/spaceimages/details.php?id=PIA23932" data-thumbnail="/spaceimages/images/wallpaper/PIA23932-640x350.jpg" data-title="Arsia Mons Summit">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 26, 2020</h3>
# <div class="item_tease_overlay">Arsia Mons Summit</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Arsia Mons Summit" class="thumb" src="/spaceimages/images/wallpaper/PIA23932-640x350.jpg" title="Arsia Mons Summit"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 26, 2020</div>
# <div class="content_title">
# 										  Arsia Mons Summit
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of the summit caldera on Arsia Mons.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the eastern flank of Arsia Mons, the southernmost aligned volcano in the Tharsis region." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23931_hires.jpg" data-link="/spaceimages/details.php?id=PIA23931" data-thumbnail="/spaceimages/images/wallpaper/PIA23931-640x350.jpg" data-title="Arsia Mons">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 25, 2020</h3>
# <div class="item_tease_overlay">Arsia Mons</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Arsia Mons" class="thumb" src="/spaceimages/images/wallpaper/PIA23931-640x350.jpg" title="Arsia Mons"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 25, 2020</div>
# <div class="content_title">
# 										  Arsia Mons
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows the eastern flank of Arsia Mons, the southernmost aligned volcano in the Tharsis region.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows layering of surface materials in Meridiani Planum." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23930_hires.jpg" data-link="/spaceimages/details.php?id=PIA23930" data-thumbnail="/spaceimages/images/wallpaper/PIA23930-640x350.jpg" data-title="Meridiani Planum">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 22, 2020</h3>
# <div class="item_tease_overlay">Meridiani Planum</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Meridiani Planum" class="thumb" src="/spaceimages/images/wallpaper/PIA23930-640x350.jpg" title="Meridiani Planum"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 22, 2020</div>
# <div class="content_title">
# 										  Meridiani Planum
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows layering of surface materials in Meridiani Planum.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows evidence of long term wind action and erosion east of Eumenides Dorsum." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23929_hires.jpg" data-link="/spaceimages/details.php?id=PIA23929" data-thumbnail="/spaceimages/images/wallpaper/PIA23929-640x350.jpg" data-title="Wind Erosion">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 21, 2020</h3>
# <div class="item_tease_overlay">Wind Erosion</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Wind Erosion" class="thumb" src="/spaceimages/images/wallpaper/PIA23929-640x350.jpg" title="Wind Erosion"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 21, 2020</div>
# <div class="content_title">
# 										  Wind Erosion
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows evidence of long term wind action and erosion east of Eumenides Dorsum.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows flank flows on the east side of Olympus Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23928_hires.jpg" data-link="/spaceimages/details.php?id=PIA23928" data-thumbnail="/spaceimages/images/wallpaper/PIA23928-640x350.jpg" data-title="Olympus Mons Lava Flows">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 20, 2020</h3>
# <div class="item_tease_overlay">Olympus Mons Lava Flows</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Olympus Mons Lava Flows" class="thumb" src="/spaceimages/images/wallpaper/PIA23928-640x350.jpg" title="Olympus Mons Lava Flows"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 20, 2020</div>
# <div class="content_title">
# 										  Olympus Mons Lava Flows
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows flank flows on the east side of Olympus Mons.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the extensive lava flows that comprise Daedalia Planum." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23927_hires.jpg" data-link="/spaceimages/details.php?id=PIA23927" data-thumbnail="/spaceimages/images/wallpaper/PIA23927-640x350.jpg" data-title="Daedalia Planum">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 19, 2020</h3>
# <div class="item_tease_overlay">Daedalia Planum</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Daedalia Planum" class="thumb" src="/spaceimages/images/wallpaper/PIA23927-640x350.jpg" title="Daedalia Planum"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 19, 2020</div>
# <div class="content_title">
# 										  Daedalia Planum
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of the extensive lava flows that comprise Daedalia Planum.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of an unnamed channel in Arabia Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23926_hires.jpg" data-link="/spaceimages/details.php?id=PIA23926" data-thumbnail="/spaceimages/images/wallpaper/PIA23926-640x350.jpg" data-title="Arabia Terra Channel">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 18, 2020</h3>
# <div class="item_tease_overlay">Arabia Terra Channel</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Arabia Terra Channel" class="thumb" src="/spaceimages/images/wallpaper/PIA23926-640x350.jpg" title="Arabia Terra Channel"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 18, 2020</div>
# <div class="content_title">
# 										  Arabia Terra Channel
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of an unnamed channel in Arabia Terra.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the region where flank flows from Olympus Mons meet the surrounding lava plains." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23910_hires.jpg" data-link="/spaceimages/details.php?id=PIA23910" data-thumbnail="/spaceimages/images/wallpaper/PIA23910-640x350.jpg" data-title="Olympus Mons Lava Flows">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 15, 2020</h3>
# <div class="item_tease_overlay">Olympus Mons Lava Flows</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Olympus Mons Lava Flows" class="thumb" src="/spaceimages/images/wallpaper/PIA23910-640x350.jpg" title="Olympus Mons Lava Flows"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 15, 2020</div>
# <div class="content_title">
# 										  Olympus Mons Lava Flows
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows the region where flank flows from Olympus Mons meet the surrounding lava plains.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the Memnonia Fossae graben." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23909_hires.jpg" data-link="/spaceimages/details.php?id=PIA23909" data-thumbnail="/spaceimages/images/wallpaper/PIA23909-640x350.jpg" data-title="Memnonia Fossae">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 14, 2020</h3>
# <div class="item_tease_overlay">Memnonia Fossae</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Memnonia Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23909-640x350.jpg" title="Memnonia Fossae"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 14, 2020</div>
# <div class="content_title">
# 										  Memnonia Fossae
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of the Memnonia Fossae graben.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows some of the linear depressions that comprise Nili Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23908_hires.jpg" data-link="/spaceimages/details.php?id=PIA23908" data-thumbnail="/spaceimages/images/wallpaper/PIA23908-640x350.jpg" data-title="Nili Fossae">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 13, 2020</h3>
# <div class="item_tease_overlay">Nili Fossae</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Nili Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23908-640x350.jpg" title="Nili Fossae"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 13, 2020</div>
# <div class="content_title">
# 										  Nili Fossae
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows some of the linear depressions that comprise Nili Fossae.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the surface on the western margin of Zephyria Planum. Zephyria Planum is located south of Elysium Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23907_hires.jpg" data-link="/spaceimages/details.php?id=PIA23907" data-thumbnail="/spaceimages/images/wallpaper/PIA23907-640x350.jpg" data-title="Zephyria Planum">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 12, 2020</h3>
# <div class="item_tease_overlay">Zephyria Planum</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Zephyria Planum" class="thumb" src="/spaceimages/images/wallpaper/PIA23907-640x350.jpg" title="Zephyria Planum"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 12, 2020</div>
# <div class="content_title">
# 										  Zephyria Planum
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows the surface on the western margin of Zephyria Planum. Zephyria Planum is located south of Elysium Planitia.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Hydraotes Chaos. Hydraotes Chaos lies in a valley leading northeast out of Ganges Chasma at the east end of Valles Marineris." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23906_hires.jpg" data-link="/spaceimages/details.php?id=PIA23906" data-thumbnail="/spaceimages/images/wallpaper/PIA23906-640x350.jpg" data-title="Hydraotes Chaos">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 11, 2020</h3>
# <div class="item_tease_overlay">Hydraotes Chaos</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Hydraotes Chaos" class="thumb" src="/spaceimages/images/wallpaper/PIA23906-640x350.jpg" title="Hydraotes Chaos"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 11, 2020</div>
# <div class="content_title">
# 										  Hydraotes Chaos
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of Hydraotes Chaos. Hydraotes Chaos lies in a valley leading northeast out of Ganges Chasma at the east end of Valles Marineris.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the floor of the huge de Vaucouleurs Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23905_hires.jpg" data-link="/spaceimages/details.php?id=PIA23905" data-thumbnail="/spaceimages/images/wallpaper/PIA23905-640x350.jpg" data-title="de Vaucouleurs Crater">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 8, 2020</h3>
# <div class="item_tease_overlay">de Vaucouleurs Crater</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="de Vaucouleurs Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23905-640x350.jpg" title="de Vaucouleurs Crater"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 8, 2020</div>
# <div class="content_title">
# 										  de Vaucouleurs Crater
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of the floor of the huge de Vaucouleurs Crater.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of unnamed channel in Libya Montes." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23904_hires.jpg" data-link="/spaceimages/details.php?id=PIA23904" data-thumbnail="/spaceimages/images/wallpaper/PIA23904-640x350.jpg" data-title="Libya Montes Channel">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 7, 2020</h3>
# <div class="item_tease_overlay">Libya Montes Channel</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Libya Montes Channel" class="thumb" src="/spaceimages/images/wallpaper/PIA23904-640x350.jpg" title="Libya Montes Channel"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 7, 2020</div>
# <div class="content_title">
# 										  Libya Montes Channel
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a section of unnamed channel in Libya Montes.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a portion of Shalbatana Vallis." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23903_hires.jpg" data-link="/spaceimages/details.php?id=PIA23903" data-thumbnail="/spaceimages/images/wallpaper/PIA23903-640x350.jpg" data-title="Shalbatana Vallis">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 6, 2020</h3>
# <div class="item_tease_overlay">Shalbatana Vallis</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Shalbatana Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23903-640x350.jpg" title="Shalbatana Vallis"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 6, 2020</div>
# <div class="content_title">
# 										  Shalbatana Vallis
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a portion of Shalbatana Vallis.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of an unnamed channel in Terra Cimmeria." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23902_hires.jpg" data-link="/spaceimages/details.php?id=PIA23902" data-thumbnail="/spaceimages/images/wallpaper/PIA23902-640x350.jpg" data-title="Terra Cimmeria Channel">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 5, 2020</h3>
# <div class="item_tease_overlay">Terra Cimmeria Channel</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Terra Cimmeria Channel" class="thumb" src="/spaceimages/images/wallpaper/PIA23902-640x350.jpg" title="Terra Cimmeria Channel"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 5, 2020</div>
# <div class="content_title">
# 										  Terra Cimmeria Channel
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a section of an unnamed channel in Terra Cimmeria.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a small portion of the immense lava flows that originated from Arsia Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23901_hires.jpg" data-link="/spaceimages/details.php?id=PIA23901" data-thumbnail="/spaceimages/images/wallpaper/PIA23901-640x350.jpg" data-title="Daedalia Planum">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 4, 2020</h3>
# <div class="item_tease_overlay">Daedalia Planum</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Daedalia Planum" class="thumb" src="/spaceimages/images/wallpaper/PIA23901-640x350.jpg" title="Daedalia Planum"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 4, 2020</div>
# <div class="content_title">
# 										  Daedalia Planum
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a small portion of the immense lava flows that originated from Arsia Mons.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows one of the small channels in Locras Valles." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23860_hires.jpg" data-link="/spaceimages/details.php?id=PIA23860" data-thumbnail="/spaceimages/images/wallpaper/PIA23860-640x350.jpg" data-title="Locras Valles">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">May 1, 2020</h3>
# <div class="item_tease_overlay">Locras Valles</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Locras Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23860-640x350.jpg" title="Locras Valles"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">May 1, 2020</div>
# <div class="content_title">
# 										  Locras Valles
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows one of the small channels in Locras Valles.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Mamers Valles. The channel is nearly 1000 km long (600 miles)." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23859_hires.jpg" data-link="/spaceimages/details.php?id=PIA23859" data-thumbnail="/spaceimages/images/wallpaper/PIA23859-640x350.jpg" data-title="Mamers Valles">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 30, 2020</h3>
# <div class="item_tease_overlay">Mamers Valles</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Mamers Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23859-640x350.jpg" title="Mamers Valles"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 30, 2020</div>
# <div class="content_title">
# 										  Mamers Valles
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a section of Mamers Valles. The channel is nearly 1000 km long (600 miles).
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Kasei Valles. This complex channel arose in the Tharsis voclanic region and flowed eastward into Chryse Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23858_hires.jpg" data-link="/spaceimages/details.php?id=PIA23858" data-thumbnail="/spaceimages/images/wallpaper/PIA23858-640x350.jpg" data-title="Kasei Valles">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 29, 2020</h3>
# <div class="item_tease_overlay">Kasei Valles</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Kasei Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23858-640x350.jpg" title="Kasei Valles"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 29, 2020</div>
# <div class="content_title">
# 										  Kasei Valles
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a section of Kasei Valles. This complex channel arose in the Tharsis voclanic region and flowed eastward into Chryse Planitia.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the floor of Orson Welles Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23857_hires.jpg" data-link="/spaceimages/details.php?id=PIA23857" data-thumbnail="/spaceimages/images/wallpaper/PIA23857-640x350.jpg" data-title="Orson Welles Crater Chaos">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 28, 2020</h3>
# <div class="item_tease_overlay">Orson Welles Crater Chaos</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Orson Welles Crater Chaos" class="thumb" src="/spaceimages/images/wallpaper/PIA23857-640x350.jpg" title="Orson Welles Crater Chaos"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 28, 2020</div>
# <div class="content_title">
# 										  Orson Welles Crater Chaos
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of the floor of Orson Welles Crater.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Sirenum Fossae. The linear depression was created by tectonic forces stretching the surface." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23856_hires.jpg" data-link="/spaceimages/details.php?id=PIA23856" data-thumbnail="/spaceimages/images/wallpaper/PIA23856-640x350.jpg" data-title="Sirenum Fossae">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 27, 2020</h3>
# <div class="item_tease_overlay">Sirenum Fossae</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Sirenum Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23856-640x350.jpg" title="Sirenum Fossae"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 27, 2020</div>
# <div class="content_title">
# 										  Sirenum Fossae
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a section of Sirenum Fossae. The linear depression was created by tectonic forces stretching the surface.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a portion of Kasei Valles. Kasei Valles is one of the largest outflow channel systems on Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23845_hires.jpg" data-link="/spaceimages/details.php?id=PIA23845" data-thumbnail="/spaceimages/images/wallpaper/PIA23845-640x350.jpg" data-title="Kasei Valles">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 24, 2020</h3>
# <div class="item_tease_overlay">Kasei Valles</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Kasei Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23845-640x350.jpg" title="Kasei Valles"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 24, 2020</div>
# <div class="content_title">
# 										  Kasei Valles
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a portion of Kasei Valles. Kasei Valles is one of the largest outflow channel systems on Mars.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows linear depressions, part of Sirenum Fossae. These depressions are called graben, which form by the down drop of material between two parallel faults." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23844_hires.jpg" data-link="/spaceimages/details.php?id=PIA23844" data-thumbnail="/spaceimages/images/wallpaper/PIA23844-640x350.jpg" data-title="Sirenum Fossae">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 23, 2020</h3>
# <div class="item_tease_overlay">Sirenum Fossae</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Sirenum Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23844-640x350.jpg" title="Sirenum Fossae"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 23, 2020</div>
# <div class="content_title">
# 										  Sirenum Fossae
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows linear depressions, part of Sirenum Fossae. These depressions are called graben, which form by the down drop of material between two parallel faults.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Ares Vallis. Ares Vallis is a large channel that arises in Iani Chaos, passes through Margaritifer Terra, and then empties into Chryse Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23843_hires.jpg" data-link="/spaceimages/details.php?id=PIA23843" data-thumbnail="/spaceimages/images/wallpaper/PIA23843-640x350.jpg" data-title="Ares Vallis">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 22, 2020</h3>
# <div class="item_tease_overlay">Ares Vallis</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Ares Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23843-640x350.jpg" title="Ares Vallis"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 22, 2020</div>
# <div class="content_title">
# 										  Ares Vallis
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a section of Ares Vallis. Ares Vallis is a large channel that arises in Iani Chaos, passes through Margaritifer Terra, and then empties into Chryse Planitia.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows several windstreaks on lava plains southwest of Arsia Mons. The extensive lava flow field is called Daedalia Planum." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23842_hires.jpg" data-link="/spaceimages/details.php?id=PIA23842" data-thumbnail="/spaceimages/images/wallpaper/PIA23842-640x350.jpg" data-title="Daedalia Planum Windstreaks">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 21, 2020</h3>
# <div class="item_tease_overlay">Daedalia Planum Windstreaks</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Daedalia Planum Windstreaks" class="thumb" src="/spaceimages/images/wallpaper/PIA23842-640x350.jpg" title="Daedalia Planum Windstreaks"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 21, 2020</div>
# <div class="content_title">
# 										  Daedalia Planum Windstreaks
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows several windstreaks on lava plains southwest of Arsia Mons. The extensive lava flow field is called Daedalia Planum.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the summit of Ascraeus Mons. Ascraeus Mons is the northernmost of the three aligned Tharsis volcanoes." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23841_hires.jpg" data-link="/spaceimages/details.php?id=PIA23841" data-thumbnail="/spaceimages/images/wallpaper/PIA23841-640x350.jpg" data-title="Ascraeus Mons">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 20, 2020</h3>
# <div class="item_tease_overlay">Ascraeus Mons</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Ascraeus Mons" class="thumb" src="/spaceimages/images/wallpaper/PIA23841-640x350.jpg" title="Ascraeus Mons"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 20, 2020</div>
# <div class="content_title">
# 										  Ascraeus Mons
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows the summit of Ascraeus Mons. Ascraeus Mons is the northernmost of the three aligned Tharsis volcanoes.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on March 29, 2020 by NASAs Mars Reconnaissance Orbiter, shows a pitted, blocky surface, but also more unusually, it has contorted, irregular features." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23855_hires.jpg" data-link="/spaceimages/details.php?id=PIA23855" data-thumbnail="/spaceimages/images/wallpaper/PIA23855-640x350.jpg" data-title="Disrupted Sediments in Acidalia Planitia">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 17, 2020</h3>
# <div class="item_tease_overlay">Disrupted Sediments in Acidalia Planitia</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Disrupted Sediments in Acidalia Planitia" class="thumb" src="/spaceimages/images/wallpaper/PIA23855-640x350.jpg" title="Disrupted Sediments in Acidalia Planitia"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 17, 2020</div>
# <div class="content_title">
# 										  Disrupted Sediments in Acidalia Planitia
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on March 29, 2020 by NASAs Mars Reconnaissance Orbiter, shows a pitted, blocky surface, but also more unusually, it has contorted, irregular features.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on March 27, 2020 by NASAs Mars Reconnaissance Orbiter, shows a couple of dark lineations on the equator-facing wall of this impact crater that resemble small recurring slope lineae (RSL)." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23854_hires.jpg" data-link="/spaceimages/details.php?id=PIA23854" data-thumbnail="/spaceimages/images/wallpaper/PIA23854-640x350.jpg" data-title="Keeping a Watchful Eye">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 17, 2020</h3>
# <div class="item_tease_overlay">Keeping a Watchful Eye</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Keeping a Watchful Eye" class="thumb" src="/spaceimages/images/wallpaper/PIA23854-640x350.jpg" title="Keeping a Watchful Eye"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 17, 2020</div>
# <div class="content_title">
# 										  Keeping a Watchful Eye
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on March 27, 2020 by NASAs Mars Reconnaissance Orbiter, shows a couple of dark lineations on the equator-facing wall of this impact crater that resemble small recurring slope lineae (RSL).
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on March 19, 2020 by NASAs Mars Reconnaissance Orbiter, shows gullies in the sand dunes of Matara Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23853_hires.jpg" data-link="/spaceimages/details.php?id=PIA23853" data-thumbnail="/spaceimages/images/wallpaper/PIA23853-640x350.jpg" data-title="An Active Gully in Matara Crater">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 17, 2020</h3>
# <div class="item_tease_overlay">An Active Gully in Matara Crater</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="An Active Gully in Matara Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23853-640x350.jpg" title="An Active Gully in Matara Crater"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 17, 2020</div>
# <div class="content_title">
# 										  An Active Gully in Matara Crater
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on March 19, 2020 by NASAs Mars Reconnaissance Orbiter, shows gullies in the sand dunes of Matara Crater.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on March 18, 2020 by NASAs Mars Reconnaissance Orbiter, shows two different targets at once, a geologically-young crater and a small even younger one." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23852_hires.jpg" data-link="/spaceimages/details.php?id=PIA23852" data-thumbnail="/spaceimages/images/wallpaper/PIA23852-640x350.jpg" data-title="Two Young Craters">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 17, 2020</h3>
# <div class="item_tease_overlay">Two Young Craters</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Two Young Craters" class="thumb" src="/spaceimages/images/wallpaper/PIA23852-640x350.jpg" title="Two Young Craters"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 17, 2020</div>
# <div class="content_title">
# 										  Two Young Craters
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on March 18, 2020 by NASAs Mars Reconnaissance Orbiter, shows two different targets at once, a geologically-young crater and a small even younger one.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a small portion of Daedalia Planum. Daedalia Planum is an immense lava flow field that originates at Arsia Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23840_hires.jpg" data-link="/spaceimages/details.php?id=PIA23840" data-thumbnail="/spaceimages/images/wallpaper/PIA23840-640x350.jpg" data-title="Daedalia Planum">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 17, 2020</h3>
# <div class="item_tease_overlay">Daedalia Planum</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Daedalia Planum" class="thumb" src="/spaceimages/images/wallpaper/PIA23840-640x350.jpg" title="Daedalia Planum"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 17, 2020</div>
# <div class="content_title">
# 										  Daedalia Planum
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a small portion of Daedalia Planum. Daedalia Planum is an immense lava flow field that originates at Arsia Mons.
# 										</div>
# </div>
# </div>
# </a>]

# %%
pic_src = []
for image in images:
    pic = image['data-fancybox-href']
    pic_src.append(pic)

featured_image_url = 'https://www.jpl.nasa.gov' + pic
featured_image_url
# Out:
# 'https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA23840_hires.jpg'

# %%
# Mars Weather

url = ('https://twitter.com/marswxreport?lang=en')

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# print(soup.prettify())

# %%
contents = soup.find_all("div",class_="content")
print(contents)
# Out:
# [<div class="content">
# <div class="stream-item-header">
# <a class="account-group js-account-group js-action-profile js-user-profile-link js-nav" data-user-id="1266281" href="/fcain">
# <img alt="" class="avatar js-action-profile-avatar" src="https://pbs.twimg.com/profile_images/1105564800753393664/KczfG4A-_bigger.png"/>
# <span class="FullNameGroup">
# <strong class="fullname show-popup-with-id u-textTruncate" data-aria-label-part="">
a></p>
# </div>
# <div class="AdaptiveMediaOuterContainer">
# <div class="AdaptiveMedia is-video has-autoplayable-media">
# <div class="AdaptiveMedia-container">
# <div class="AdaptiveMedia-video">
# <div class="AdaptiveMedia-videoContainer">
# <div class="PlayableMedia PlayableMedia--video">
# <div class="PlayableMedia-container">
# <div class="PlayableMedia-player" data-border-bottom-left-radius="" data-border-bottom-right-radius="" data-border-top-left-radius="" data-border-top-right-radius="" data-playable-media-url="" data-use-b-version-of-react-player="" data-use-player-precache="" data-use-react-player="" style="padding-bottom: 56.25%; background-image:url('https://pbs.twimg.com/ext_tw_video_thumb/1258731134051065857/pu/img/Byrq44VzVhi3aM1y.jpg')">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="stream-item-footer">
# <div class="ProfileTweet-actionCountList u-hiddenVisually">
# <span class="ProfileTweet-action--reply u-hiddenVisually">
# <span class="ProfileTweet-actionCount" data-tweet-stat-count="3">
# <span class="ProfileTweet-actionCountForAria" data-aria-label-part="" id="profile-tweet-action-reply-count-aria-1258731844624887809">3 replies</span>
# </span>
# </span>
# <span class="ProfileTweet-action--retweet u-hiddenVisually">
# <span class="ProfileTweet-actionCount" data-tweet-stat-count="53">
# <span class="ProfileTweet-actionCountForAria" data-aria-label-part="" id="profile-tweet-action-retweet-count-aria-1258731844624887809">53 retweets</span>
# </span>
# </span>
# <span class="ProfileTweet-action--favorite u-hiddenVisually">
# <span class="ProfileTweet-actionCount" data-tweet-stat-count="133">
# <span class="ProfileTweet-actionCountForAria" data-aria-label-part="" id="profile-tweet-action-favorite-count-aria-1258731844624887809">133 likes</span>
# </span>
# </span>
# </div>
# <div aria-label="Tweet actions" class="ProfileTweet-actionList js-actions" role="group">
# <div class="ProfileTweet-action ProfileTweet-action--reply">
# <button aria-describedby="profile-tweet-action-reply-count-aria-1258731844624887809" class="ProfileTweet-actionButton js-actionButton js-actionReply" data-modal="ProfileTweet-reply" type="button">
# <div class="IconContainer js-tooltip" title="Reply">
# <span class="Icon Icon--medium Icon--reply"></span>
# <span class="u-hiddenVisually">Reply</span>
# </div>
# <span class="ProfileTweet-actionCount">
# <span aria-hidden="true" class="ProfileTweet-actionCountForPresentation">3</span>
# </span>
# </button>
# </div>
# <div class="ProfileTweet-action ProfileTweet-action--retweet js-toggleState js-toggleRt">
# <button aria-describedby="profile-tweet-action-retweet-count-aria-1258731844624887809" class="ProfileTweet-actionButton js-actionButton js-actionRetweet" data-modal="ProfileTweet-retweet" type="button">
# <div class="IconContainer js-tooltip" title="Retweet">
# <span class="Icon Icon--medium Icon--retweet"></span>
# <span class="u-hiddenVisually">Retweet</span>
# </div>
# <span class="ProfileTweet-actionCount">
# <span aria-hidden="true" class="ProfileTweet-actionCountForPresentation">53</span>
# </span>
# </button><button class="ProfileTweet-actionButtonUndo js-actionButton js-actionRetweet" data-modal="ProfileTweet-retweet" type="button">
# <div class="IconContainer js-tooltip" title="Undo retweet">
# <span class="Icon Icon--medium Icon--retweet"></span>
# <span class="u-hiddenVisually">Retweeted</span>
# </div>
# <span class="ProfileTweet-actionCount">
# <span aria-hidden="true" class="ProfileTweet-actionCountForPresentation">53</span>
# </span>
# </button>
# </div>
# <div class="ProfileTweet-action ProfileTweet-action--favorite js-toggleState">
# <button aria-describedby="profile-tweet-action-favorite-count-aria-1258731844624887809" class="ProfileTweet-actionButton js-actionButton js-actionFavorite" type="button">
# <div class="IconContainer js-tooltip" title="Like">
# <span class="Icon Icon--heart Icon--medium" role="presentation"></span>
# <div class="HeartAnimation"></div>
# <span class="u-hiddenVisually">Like</span>
# </div>
# <span class="ProfileTweet-actionCount">
# <span aria-hidden="true" class="ProfileTweet-actionCountForPresentation">133</span>
# </span>
# </button><button class="ProfileTweet-actionButtonUndo ProfileTweet-action--unfavorite u-linkClean js-actionButton js-actionFavorite" type="button">
# <div class="IconContainer js-tooltip" title="Undo like">
# <span class="Icon Icon--heart Icon--medium" role="presentation"></span>
# <div class="HeartAnimation"></div>
# <span class="u-hiddenVisually">Liked</span>
# </div>
# <span class="ProfileTweet-actionCount">
# <span aria-hidden="true" class="ProfileTweet-actionCountForPresentation">133</span>
# </span>
# </button>
# </div>
# </div>
# </div>
# </div>]

# %%
weather_mars = []
for content in contents:
    tweet = content.find("div", class_="js-tweet-text-container").text
    weather_mars.append(tweet)
# print(weather_mars)

mars_weather = weather_mars[0]
print(mars_weather)
# Out:
# Mars doesn't have much of a magnetosphere, but here's a map -  https://www.nasa.gov/press-release/goddard/2020/mars-electric-currents …pic.twitter.com/v6QGHUNZv5

# %%
# Mars Facts

mars_facts_url = "https://space-facts.com/mars/"
table = pd.read_html(mars_facts_url)
table[0]
# Out:
#                       0                              1
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
mars_facts_df = table[0]
mars_facts_df.columns = ["Facts", "Value"]
mars_facts_df.set_index(["Facts"])
mars_facts_df
# Out:
#                   Facts                          Value
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
facts_html = mars_facts_df.to_html()
facts_html = facts_html.replace("\n","")
facts_html
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Facts</th>      <th>Value</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>Equatorial Diameter:</td>      <td>6,792 km</td>    </tr>    <tr>      <th>1</th>      <td>Polar Diameter:</td>      <td>6,752 km</td>    </tr>    <tr>      <th>2</th>      <td>Mass:</td>      <td>6.39 × 10^23 kg (0.11 Earths)</td>    </tr>    <tr>      <th>3</th>      <td>Moons:</td>      <td>2 (Phobos &amp; Deimos)</td>    </tr>    <tr>      <th>4</th>      <td>Orbit Distance:</td>      <td>227,943,824 km (1.38 AU)</td>    </tr>    <tr>      <th>5</th>      <td>Orbit Period:</td>      <td>687 days (1.9 years)</td>    </tr>    <tr>      <th>6</th>      <td>Surface Temperature:</td>      <td>-87 to -5 °C</td>    </tr>    <tr>      <th>7</th>      <td>First Record:</td>      <td>2nd millennium BC</td>    </tr>    <tr>      <th>8</th>      <td>Recorded By:</td>      <td>Egyptian astronomers</td>    </tr>  </tbody></table>'

# %%
# Mars Hemispheres

hemisphere_image_urls = []

# %%
# Cerberus

url = ('https://astrogeology.usgs.gov/search/map/Mars/Viking/cerberus_enhanced')

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# print(soup.prettify())

# %%
cerberus_img = soup.find_all('div', class_="wide-image-wrapper")
print(cerberus_img)
# Out:
# [<div class="wide-image-wrapper" id="wide-image">
# <div class="downloads">
# <img class="thumb" src="/cache/images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/>
# <h3>Download</h3>
# <ul>
# <li><a href="https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg" target="_blank">Sample</a> (jpg) 1024px wide</li>
# <li><a href="https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif" target="_blank">Original</a> (tif) 21 MB</li>
# </ul>
# </div>
# <img class="wide-image" src="/cache/images/f5e372a36edfa389625da6d0cc25d905_cerberus_enhanced.tif_full.jpg"/>
# <a class="open-toggle" href="#open" id="wide-image-toggle">Open</a>
# </div>]

# %%
for img in cerberus_img:
    pic = img.find('li')
    full_img = pic.find('a')['href']
    print(full_img)
cerberus_title = soup.find('h2', class_='title').text
print(cerberus_title)
cerberus_hem = {"Title": cerberus_title, "url": full_img}
print(cerberus_hem)
# Out:
# https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg
# Cerberus Hemisphere Enhanced
# {'Title': 'Cerberus Hemisphere Enhanced', 'url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg'}

# %%
# Schiaparelli

url = ('https://astrogeology.usgs.gov/search/map/Mars/Viking/schiaparelli_enhanced')

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
schiaparelli_img = soup.find_all('div', class_="wide-image-wrapper")
print(schiaparelli_img)
# Out:
# [<div class="wide-image-wrapper" id="wide-image">
# <div class="downloads">
# <img class="thumb" src="/cache/images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/>
# <h3>Download</h3>
# <ul>
# <li><a href="https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg" target="_blank">Sample</a> (jpg) 1024px wide</li>
# <li><a href="https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif" target="_blank">Original</a> (tif) 35 MB</li>
# </ul>
# </div>
# <img class="wide-image" src="/cache/images/3778f7b43bbbc89d6e3cfabb3613ba93_schiaparelli_enhanced.tif_full.jpg"/>
# <a class="open-toggle" href="#open" id="wide-image-toggle">Open</a>
# </div>]

# %%
for img in schiaparelli_img:
    pic = img.find('li')
    full_img = pic.find('a')['href']
    print(full_img)
schiaparelli_title = soup.find('h2', class_='title').text
print(schiaparelli_title)
schiaparelli_hem = {"Title": schiaparelli_title, "url": full_img}
print(schiaparelli_hem)
# Out:
# https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg
# Schiaparelli Hemisphere Enhanced
# {'Title': 'Schiaparelli Hemisphere Enhanced', 'url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg'}

# %%
# Syrtis

url = ('https://astrogeology.usgs.gov/search/map/Mars/Viking/syrtis_major_enhanced')

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
syrtis_img = soup.find_all('div', class_="wide-image-wrapper")
print(syrtis_img)
# Out:
# [<div class="wide-image-wrapper" id="wide-image">
# <div class="downloads">
# <img class="thumb" src="/cache/images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/>
# <h3>Download</h3>
# <ul>
# <li><a href="https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg" target="_blank">Sample</a> (jpg) 1024px wide</li>
# <li><a href="https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif" target="_blank">Original</a> (tif) 25 MB</li>
# </ul>
# </div>
# <img class="wide-image" src="/cache/images/555e6403a6ddd7ba16ddb0e471cadcf7_syrtis_major_enhanced.tif_full.jpg"/>
# <a class="open-toggle" href="#open" id="wide-image-toggle">Open</a>
# </div>]

# %%
for img in syrtis_img:
    pic = img.find('li')
    full_img = pic.find('a')['href']
    print(full_img)
syrtis_title = soup.find('h2', class_='title').text
print(syrtis_title)
syrtis_hem = {"Title": syrtis_title, "url": full_img}
print(syrtis_hem)
# Out:
# https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg
# Syrtis Major Hemisphere Enhanced
# {'Title': 'Syrtis Major Hemisphere Enhanced', 'url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg'}

# %%
# Valles

url = ('https://astrogeology.usgs.gov/search/map/Mars/Viking/valles_marineris_enhanced')

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
valles_img = soup.find_all('div', class_="wide-image-wrapper")
print(valles_img)
# Out:
# [<div class="wide-image-wrapper" id="wide-image">
# <div class="downloads">
# <img class="thumb" src="/cache/images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/>
# <h3>Download</h3>
# <ul>
# <li><a href="https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg" target="_blank">Sample</a> (jpg) 1024px wide</li>
# <li><a href="https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif" target="_blank">Original</a> (tif) 27 MB</li>
# </ul>
# </div>
# <img class="wide-image" src="/cache/images/b3c7c6c9138f57b4756be9b9c43e3a48_valles_marineris_enhanced.tif_full.jpg"/>
# <a class="open-toggle" href="#open" id="wide-image-toggle">Open</a>
# </div>]

# %%
for img in valles_img:
    pic = img.find('li')
    full_img = pic.find('a')['href']
    print(full_img)
valles_title = soup.find('h2', class_='title').text
print(valles_title)
valles_hem = {"Title": valles_title, "url": full_img}
print(valles_hem)
# Out:
# https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg
# Valles Marineris Hemisphere Enhanced
# {'Title': 'Valles Marineris Hemisphere Enhanced', 'url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg'}
